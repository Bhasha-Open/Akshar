# %%
from akshar import aksharTokenizer
import akshar as ak

# %%
tokeniser = aksharTokenizer()
text = "aaj मौसम बहुत अच्छा है"

token = tokeniser.tokenize(text)

token
# clt
# Out:
# ['a',
#  'a',
#  'j',
#  ' ',
#  'मौ',
#  'स',
#  'म',
#  ' ',
#  'ब',
#  'हु',
#  'त',
#  ' ',
#  'अ',
#  'च्छा',
#  ' ',
#  'है']

# %%
# text.split()  # word level tokeniser

# %%
aks = ak.segment_akshars(text)

# %%
aks # matra se alag bhi nahi kar parha
# Out:
# ['a',
#  'a',
#  'j',
#  ' ',
#  'मौ',
#  'स',
#  'म',
#  ' ',
#  'ब',
#  'हु',
#  'त',
#  ' ',
#  'अ',
#  'च्छा',
#  ' ',
#  'है']

# %%
t = "सी"

# a = ak.segment_akshars(t,matras=
a
# Out:
# ['स', 'ी']
